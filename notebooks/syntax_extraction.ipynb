# %%
# !python -m spacy download en_core_web_trf
# !pip install spacy
# !pip install spacy-transformers

# %%
import spacy
import spacy_transformers
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
import pandas as pd
import requests
from tqdm import tqdm
from collections import Counter
import json

# %%
lit_df = pd.read_csv('literature.csv')
lit_df = lit_df[lit_df['author']!='William Shakespeare']
lit_df

# %%
nlp = spacy.load("en_core_web_trf")

# %%
lit_df[lit_df['author']=='Jane Austen'].iloc[0]['url']
lit_df[lit_df['author']=='Jane Austen'].iloc[0]['title']
# Out:
# 'Sense and Sensibility'

# %%
def extract_adjective_noun_pairs(url):
  page = requests.get(url)
  clean_text = ('\r\n\r\n').join([x for x in page.text.split('\r\n\r\n') if 'gutenberg' not in x.lower()]).split('START: FULL LICENSE')[0]
  split_text = clean_text.split('\n')
  
  results = []
  for entry in tqdm(split_text):
    doc = nlp(entry)
    for token in doc:
        if (token.dep_ == 'amod') & (token.head.pos_ == 'NOUN'):
          results.append(('amod',token.text,token.head.text))
  
  counter = Counter(results)

  return counter.most_common()

test = extract_adjective_noun_pairs('https://www.gutenberg.org/files/161/161-0.txt')
# Out:
# 100%|██████████| 12693/12693 [24:40<00:00,  8.57it/s]

# %%
def create_network_data(data, title, source='adjective',target='noun', threshold=3):
  nodes = [{"id":x[0][1],"type":source} for x in data if x[1] > threshold] + [{"id":x[0][2],"type":target} for x in data if x[1] > threshold]
  nodes = list({v['id']:v for v in nodes}.values())
  links = [{"source":x[0][1],"target":x[0][2],"count":x[1]} for x in data if x[1] > threshold]
  
  dumps = json.dumps({"nodes":nodes,"links":links}, indent=4)  

  with open(f"/content/drive/MyDrive/NLP_2023/pos_network_data/{title}-{source}-{target}.json", "w") as outfile:
      outfile.write(dumps)
 
  return nodes

# %%
def extract_all(df):
  for idx in range(len(df)):
    title = df.iloc[idx]['title'].lower().replace(' ','-')
    data = extract_adjective_noun_pairs(df.iloc[idx]['url'])
    create_network_data(data, title, source='adjective',target='noun', threshold=3)
    print(title)
  
extract_all(lit_df)
# Out:
# 100%|██████████| 4455/4455 [09:32<00:00,  7.79it/s]
# a-tale-of-the-tub
# 100%|██████████| 22306/22306 [49:57<00:00,  7.44it/s]
# the-journal-to-stella
# 100%|██████████| 9199/9199 [18:39<00:00,  8.22it/s]
# the-prose-works-of-jonathan-swift
# 100%|██████████| 9561/9561 [20:11<00:00,  7.89it/s]
# gulliver's-travels
# 100%|██████████| 12693/12693 [25:15<00:00,  8.38it/s]
# sense-and-sensibility
# 100%|██████████| 14550/14550 [27:21<00:00,  8.87it/s]
# pride-and-prejudice
# 100%|██████████| 15692/15692 [30:37<00:00,  8.54it/s]
# mansfield-park
# 100%|██████████| 16510/16510 [32:15<00:00,  8.53it/s]
# emma
# 100%|██████████| 8375/8375 [16:03<00:00,  8.69it/s]
# persuasion
# 100%|██████████| 8014/8014 [15:26<00:00,  8.65it/s]
# northanger-abbey
# 100%|██████████| 7381/7381 [14:10<00:00,  8.68it/s]
# frankenstein
# 100%|██████████| 4631/4631 [09:09<00:00,  8.42it/s]
# mathilda
# 100%|██████████| 16557/16557 [33:02<00:00,  8.35it/s]
# the-last-man
# 100%|██████████| 18831/18831 [35:57<00:00,  8.73it/s]
# oliver-twist
# 100%|██████████| 38218/38218 [1:14:59<00:00,  8.49it/s]
# david-copperfield
# 100%|██████████| 39870/39870 [1:14:53<00:00,  8.87it/s]
# bleak-house
# 100%|██████████| 11674/11674 [24:10<00:00,  8.05it/s]
# hard-times
# 100%|██████████| 15924/15924 [31:16<00:00,  8.49it/s]
# a-tale-of-two-cities
# 100%|██████████| 20417/20417 [41:53<00:00,  8.12it/s]
# great-expectations
# 100%|██████████| 18752/18752 [38:16<00:00,  8.17it/s]
# innocents-abroad
# 100%|██████████| 8894/8894 [17:56<00:00,  8.26it/s]
# the-adventures-of-tom-sawyer
# 100%|██████████| 14834/14834 [29:06<00:00,  8.49it/s]
# life-on-the-mississippi
# 100%|██████████| 8176/8176 [16:24<00:00,  8.31it/s]
# the-prince-and-the-pauper
# 100%|██████████| 12031/12031 [24:01<00:00,  8.35it/s]
# adventures-of-huckleberry-finn
# 100%|██████████| 12863/12863 [24:56<00:00,  8.59it/s]
# a-connecticut-yankee-in-king-arthur's-court
# 100%|██████████| 5972/5972 [11:31<00:00,  8.64it/s]
# the-tragedy-of-pudd'nhead-wilson
# 100%|██████████| 3195/3195 [06:31<00:00,  8.17it/s]
# the-time-machine
# 100%|██████████| 4736/4736 [09:23<00:00,  8.40it/s]
# the-island-of-doctor-moreau
# 100%|██████████| 5776/5776 [11:25<00:00,  8.43it/s]
# the-invisible-man
# 100%|██████████| 6388/6388 [12:54<00:00,  8.25it/s]
# the-war-of-the-worlds
# 100%|██████████| 1/1 [00:00<00:00, 1295.74it/s]
# heart-of-darkness
# 100%|██████████| 11300/11300 [25:01<00:00,  7.53it/s]
# lord-jim
#  18%|█▊        | 3148/17185 [06:34<27:49,  8.41it/s]

# %%
doc = nlp("He ran quickly up the stairs")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# He nsubj ran VERB []
# ran ROOT ran VERB [He, quickly, up]
# quickly advmod ran VERB []
# up prep ran VERB [stairs]
# the det stairs NOUN []
# stairs pobj up ADP [the]

# %%
def extract_root_pairs(url):
  
  page = requests.get(url)
  clean_text = ('\r\n\r\n').join([x for x in page.text.split('\r\n\r\n') if 'gutenberg' not in x.lower()]).split('START: FULL LICENSE')[0]
  split_text = clean_text.split('\n')
  
  results = []
  for entry in tqdm(split_text):
    doc = nlp(entry)
    for token in doc:
      if (token.dep_ == 'nsubj') & (token.pos_ == 'PROPN') & (token.head.pos_ == 'VERB'):
          result = ('nsubj',token.text,token.head.text,[x.text for x in token.rights])
          print(result)
          results.append(result)
  
  counter = Counter(results)

  return counter.most_common()

test = extract_root_pairs('https://www.gutenberg.org/files/161/161-0.txt')

# %%
test
# Out:
# [(('amod', 'old', 'gentleman'), 108),
#  (('amod', 'old', 'lady'), 65),
#  (('amod', 'young', 'lady'), 56),
#  (('amod', 'young', 'man'), 33),
#  (('amod', 'old', 'man'), 33),
#  (('amod', 'young', 'gentleman'), 28),
#  (('amod', 'old', 'woman'), 20),
#  (('amod', 'great', 'deal'), 20),
#  (('amod', 'white', 'waistcoat'), 19),
#  (('amod', 'public', 'house'), 19),
#  (('amod', 'long', 'time'), 18),
#  (('amod', 'cocked', 'hat'), 18),
#  (('amod', 'young', 'woman'), 17),
#  (('amod', 'low', 'voice'), 16),
#  (('amod', 'few', 'words'), 14),
#  (('amod', 'right', 'hand'), 13),
#  (('amod', 'poor', 'boy'), 12),
#  (('amod', 'next', 'morning'), 11),
#  (('amod', 'little', 'room'), 11),
#  (('amod', 'next', 'day'), 11),
#  (('amod', 'dear', 'lady'), 11),
#  (('amod', 'first', 'time'), 10),
#  (('amod', 'good', 'deal'), 10),
#  (('amod', 'great', 'number'), 10),
#  (('amod', 'same', 'time'), 10),
#  (('amod', 'young', 'friend'), 10),
#  (('amod', 'last', 'night'), 9),
#  (('amod', 'old', 'women'), 9),
#  (('amod', 'great', 'coat'), 9),
#  (('amod', 'good', 'lady'), 8),
#  (('amod', 'poor', 'child'), 8),
#  (('amod', 'few', 'moments'), 8),
#  (('amod', 'short', 'time'), 8),
#  (('amod', 'other', 'man'), 7),
#  (('amod', 'left', 'hand'), 6),
#  (('amod', 'many', 'years'), 6),
#  (('amod', 'latter', 'gentleman'), 6),
#  (('amod', 'many', 'people'), 6),
#  (('amod', 'Poor', 'fellow'), 6),
#  (('amod', 'many', 'times'), 6),
#  (('amod', 'little', 'time'), 6),
#  (('amod', 'good', 'humour'), 6),
#  (('amod', 'fat', 'gentleman'), 5),
#  (('amod', 'very', 'thing'), 5),
#  (('amod', 'short', 'pause'), 5),
#  (('amod', 'tall', 'man'), 5),
#  (('amod', 'tremulous', 'voice'), 5),
#  (('amod', 'dim', 'light'), 5),
#  (('amod', 'mere', 'child'), 5),
#  (('amod', 'long', 'way'), 5),
#  (('amod', 'opposite', 'side'), 5),
#  (('amod', 'new', 'friend'), 5),
#  (('amod', 'merry', 'gentleman'), 5),
#  (('amod', 'deep', 'sleep'), 5),
#  (('amod', 'other', 'boys'), 5),
#  (('amod', 'old', 'gentlemen'), 5),
#  (('amod', 'backed', 'man'), 5),
#  (('amod', 'dear', 'child'), 5),
#  (('amod', 'own', 'room'), 5),
#  (('amod', 'short', 'distance'), 5),
#  (('amod', 'such', 'things'), 5),
#  (('amod', 'full', 'length'), 5),
#  (('amod', 'good', 'night'), 5),
#  (('amod', 'great', 'distance'), 5),
#  (('amod', 'poor', 'creature'), 5),
#  (('amod', 'little', 'man'), 5),
#  (('amod', 'short', 'silence'), 5),
#  (('amod', 'elder', 'lady'), 5),
#  (('amod', 'next', 'room'), 5),
#  (('amod', 'FURTHER', 'PARTICULARS'), 4),
#  (('amod', 'pale', 'face'), 4),
#  (('amod', 'faint', 'voice'), 4),
#  (('amod', 'other', 'words'), 4),
#  (('amod', 'poor', 'man'), 4),
#  (('amod', 'kind', 'gentleman'), 4),
#  (('amod', 'young', 'rascal'), 4),
#  (('amod', 'hearted', 'man'), 4),
#  (('amod', 'other', 'hand'), 4),
#  (('amod', 'little', 'boy'), 4),
#  (('amod', 'strange', 'place'), 4),
#  (('amod', 'such', 'time'), 4),
#  (('amod', 'little', 'wretch'), 4),
#  (('amod', 'only', 'thing'), 4),
#  (('amod', 'little', 'way'), 4),
#  (('amod', 'strange', 'boy'), 4),
#  (('amod', 'public', 'houses'), 4),
#  (('amod', 'great', 'attention'), 4),
#  (('amod', 'rapid', 'pace'), 4),
#  (('amod', 'other', 'person'), 4),
#  (('amod', 'such', 'times'), 4),
#  (('amod', 'young', 'ladies'), 4),
#  (('amod', 'upper', 'end'), 4),
#  (('amod', 'new', 'friends'), 4),
#  (('amod', 'other', 'side'), 4),
#  (('amod', 'young', 'boy'), 4),
#  (('amod', 'several', 'times'), 4),
#  (('amod', 'long', 'silence'), 4),
#  (('amod', 'old', 'ladies'), 4),
#  (('amod', 'poor', 'girl'), 4),
#  (('amod', 'own', 'eyes'), 4),
#  (('amod', 'little', 'word'), 4),
#  (('amod', 'sweet', 'voice'), 4),
#  (('amod', 'half', 'way'), 4),
#  (('amod', 'anxious', 'faces'), 4),
#  (('amod', 'good', 'doctor'), 4),
#  (('amod', 'great', 'care'), 4),
#  (('amod', 'old', 'companion'), 4),
#  (('amod', 'adjoining', 'room'), 4),
#  (('amod', 'NEW', 'ASSOCIATES'), 3),
#  (('amod', 'best', 'thing'), 3),
#  (('amod', 'loud', 'cry'), 3),
#  (('amod', 'dear', 'heart'), 3),
#  (('amod', 'green', 'bottle'), 3),
#  (('amod', 'very', 'moment'), 3),
#  (('amod', 'other', 'gentleman'), 3),
#  (('amod', 'cold', 'water'), 3),
#  (('amod', 'high', 'chair'), 3),
#  (('amod', 'few', 'minutes'), 3),
#  (('amod', 'little', 'bit'), 3),
#  (('amod', 'dark', 'room'), 3),
#  (('amod', 'ill', 'usage'), 3),
#  (('amod', 'brown', 'paper'), 3),
#  (('amod', 'drab', 'breeches'), 3),
#  (('amod', 'good', 'boy'), 3),
#  (('amod', 'trembling', 'hand'), 3),
#  (('amod', 'little', 'parlour'), 3),
#  (('amod', 'looking', 'boy'), 3),
#  (('amod', 'few', 'men'), 3),
#  (('amod', 'open', 'door'), 3),
#  (('amod', 'good', 'man'), 3),
#  (('amod', 'loud', 'scream'), 3),
#  (('amod', 'good', 'one'), 3),
#  (('amod', 'half', 'quartern'), 3),
#  (('amod', 'great', 'admiration'), 3),
#  (('amod', 'young', 'fellow'), 3),
#  (('amod', 'cold', 'night'), 3),
#  (('amod', 'dark', 'night'), 3),
#  (('amod', 'open', 'street'), 3),
#  (('amod', 'little', 'bundle'), 3),
#  (('amod', 'distant', 'part'), 3),
#  (('amod', 'same', 'attitude'), 3),
#  (('amod', 'faced', 'boy'), 3),
#  (('amod', 'old', 'place'), 3),
#  (('amod', 'small', 'house'), 3),
#  (('amod', 'main', 'street'), 3),
#  (('amod', 'previous', 'night'), 3),
#  (('amod', 'old', 'gentlman'), 3),
#  (('amod', 'many', 'days'), 3),
#  (('amod', 'very', 'instant'), 3),
#  (('amod', 'new', 'comer'), 3),
#  (('amod', 'striped', 'waistcoat'), 3),
#  (('amod', 'young', 'charge'), 3),
#  (('amod', 'great', 'surprise'), 3),
#  (('amod', 'great', 'rapidity'), 3),
#  (('amod', 'half', 'dozen'), 3),
#  (('amod', 'white', 'dog'), 3),
#  (('amod', 'opposite', 'wall'), 3),
#  (('amod', 'little', 'basket'), 3),
#  (('amod', 'new', 'suit'), 3),
#  (('amod', 'little', 'while'), 3),
#  (('amod', 'young', 'heart'), 3),
#  (('amod', 'old', 'friend'), 3),
#  (('amod', 'thick', 'stick'), 3),
#  (('amod', 'extraordinary', 'thing'), 3),
#  (('amod', 'own', 'head'), 3),
#  (('amod', 'good', 'people'), 3),
#  (('amod', 'good', 'friend'), 3),
#  (('amod', 'breathless', 'state'), 3),
#  (('amod', 'half', 'boots'), 3),
#  (('amod', 'half', 'hour'), 3),
#  (('amod', 'few', 'people'), 3),
#  (('amod', 'threatening', 'look'), 3),
#  (('amod', 'good', 'time'), 3),
#  (('amod', 'early', 'morning'), 3),
#  (('amod', 'great', 'stress'), 3),
#  (('amod', 'own', 'thoughts'), 3),
#  (('amod', 'lower', 'part'), 3),
#  (('amod', 'deep', 'sigh'), 3),
#  (('amod', 'Good', 'night'), 3),
#  (('amod', 'many', 'things'), 3),
#  (('amod', 'lonely', 'place'), 3),
#  (('amod', 'hoarse', 'voice'), 3),
#  (('amod', 'same', 'way'), 3),
#  (('amod', 'sick', 'woman'), 3),
#  (('amod', 'dying', 'woman'), 3),
#  (('amod', 'young', 'mother'), 3),
#  (('amod', 'professional', 'gentleman'), 3),
#  (('amod', 'great', 'satisfaction'), 3),
#  (('amod', 'strange', 'man'), 3),
#  (('amod', 'left', 'arm'), 3),
#  (('amod', 'such', 'circumstances'), 3),
#  (('amod', 'breathless', 'interest'), 3),
#  (('amod', 'blue', 'eye'), 3),
#  (('amod', 'favourable', 'opportunity'), 3),
#  (('amod', 'bad', 'one'), 3),
#  (('amod', 'crowded', 'streets'), 3),
#  (('amod', 'high', 'spirits'), 3),
#  (('amod', 'soft', 'eye'), 3),
#  (('amod', 'young', 'creature'), 3),
#  (('amod', 'much', 'happiness'), 3),
#  (('amod', 'great', 'difficulty'), 3),
#  (('amod', 'first', 'passion'), 3),
#  (('amod', 'own', 'lips'), 3),
#  (('amod', 'last', 'time'), 3),
#  (('amod', 'small', 'room'), 3),
#  (('amod', 'same', 'manner'), 3),
#  (('amod', 'own', 'friend'), 3),
#  (('amod', 'open', 'yard'), 3),
#  (('amod', 'ANOTHER', 'PLACE'), 2),
#  (('amod', 'FIRST', 'ENTRY'), 2),
#  (('amod', 'UNFAVOURABLE', 'NOTION'), 2),
#  (('amod', 'HIGH', 'PRICE'), 2),
#  (('amod', 'BETTER', 'CARE'), 2),
#  (('amod', 'NEW', 'ACQUAINTANCES'), 2),
#  (('amod', 'VARIOUS', 'MATTERS'), 2),
#  (('amod', 'PLEASANT', 'MATTERS'), 2),
#  (('amod', 'REMARKABLE', 'PREDICTION'), 2),
#  (('amod', 'GREAT', 'MAN'), 2),
#  (('amod', 'IMPROVING', 'SOCIETY'), 2),
#  (('amod', 'NOTABLE', 'PLAN'), 2),
#  (('amod', 'PLEASANT', 'CONVERSATION'), 2),
#  (('amod', 'POOR', 'SUBJECT'), 2),
#  (('amod', 'MYSTERIOUS', 'CHARACTER'), 2),
#  (('amod', 'INSEPARABLE', 'THINGS'), 2),
#  (('amod', 'FORMER', 'CHAPTER'), 2),
#  (('amod', 'NEW', 'VISITORS'), 2),
#  (('amod', 'CRITICAL', 'POSITION'), 2),
#  (('amod', 'HAPPY', 'LIFE'), 2),
#  (('amod', 'RELATIVE', 'PARTICULARS'), 2),
#  (('amod', 'NEW', 'ADVENTURE'), 2),
#  (('amod', 'GREAT', 'IMPORTANCE'), 2),
#  (('amod', 'MATRIMONIAL', 'CASES'), 2),
#  (('amod', 'RESPECTABLE', 'CHARACTERS'), 2),
#  (('amod', 'STRANGE', 'INTERVIEW'), 2),
#  (('amod', 'LAST', 'CHAMBER'), 2),
#  (('amod', 'FRESH', 'DISCOVERIES'), 2),
#  (('amod', 'OLD', 'ACQUAINTANCE'), 2),
#  (('amod', 'PUBLIC', 'CHARACTER'), 2),
#  (('amod', 'ARTFUL', 'DODGER'), 2),
#  (('amod', 'SECRET', 'MISSION'), 2),
#  (('amod', 'MORE', 'MYSTERIES'), 2),
#  (('amod', 'LAST', 'NIGHT'), 2),
#  (('amod', 'ALIVE', 'NIGHT'), 2),
#  (('amod', 'many', 'reasons'), 2),
#  (('amod', 'particular', 'instance'), 2),
#  (('amod', 'such', 'matters'), 2),
#  (('amod', 'first', 'proof'), 2),
#  (('amod', 'evident', 'satisfaction'), 2),
#  (('amod', 'poor', 'dear'), 2),
#  (('amod', 'Poor', 'dear'), 2),
#  (('amod', 'same', 'service'), 2),
#  (('amod', 'much', 'food'), 2),
#  (('amod', 'elderly', 'female'), 2),
#  (('amod', 'greater', 'part'), 2),
#  (('amod', 'lowest', 'depth'), 2),
#  (('amod', 'experimental', 'philosopher'), 2),
#  (('amod', 'little', 'being'), 2),
#  (('amod', 'fat', 'man'), 2),
#  (('amod', 'dear', 'children'), 2),
#  (('amod', 'little', 'drop'), 2),
#  (('amod', 'leetle', 'drop'), 2),
#  (('amod', 'outer', 'coat'), 2),
#  (('amod', 'round', 'face'), 2),
#  (('amod', 'many', 'gentlemen'), 2),
#  (('amod', 'poor', 'people'), 2),
#  (('amod', 'great', 'excitement'), 2),
#  (('amod', 'first', 'sight'), 2),
#  (('amod', 'dismal', 'night'), 2),
#  (('amod', 'cold', 'surface'), 2),
#  (('amod', 'own', 'master'), 2),
#  (('amod', 'here', 'boy'), 2),
#  (('amod', 'clean', 'shirt'), 2),
#  (('amod', 'small', 'piece'), 2),
#  (('amod', 'top', 'boots'), 2),
#  (('amod', 'other', 'people'), 2),
#  (('amod', 'second', 'gentleman'), 2),
#  (('amod', 'only', 'way'), 2),
#  (('amod', 'darned', 'stockings'), 2),
#  (('amod', 'large', 'buttons'), 2),
#  (('amod', 'unoccupied', 'hand'), 2),
#  (('amod', 'few', 'seconds'), 2),
#  (('amod', 'cold', 'tremble'), 2),
#  (('amod', 'large', 'door'), 2),
#  (('amod', 'calm', 'sleep'), 2),
#  (('amod', 'new', 'boy'), 2),
#  (('amod', 'great', 'credit'), 2),
#  (('amod', 'own', 'way'), 2),
#  (('amod', 'large', 'book'), 2),
#  (('amod', 'same', 'house'), 2),
#  (('amod', 'clever', 'lad'), 2),
#  (('amod', 'wrong', 'side'), 2),
#  (('amod', 'narrow', 'street'), 2),
#  (('amod', 'young', 'girl'), 2),
#  (('amod', 'cold', 'hearth'), 2),
#  (('amod', 'large', 'cloak'), 2),
#  (('amod', 'good', 'fellow'), 2),
#  (('amod', 'few', 'paces'), 2),
#  (('amod', 'own', 'mind'), 2),
#  (('amod', 'few', 'weeks'), 2),
#  (('amod', 'many', 'opportunities'), 2),
#  (('amod', 'violent', 'fit'), 2),
#  (('amod', 'red', 'nose'), 2),
#  (('amod', 'jeering', 'tone'), 2),
#  (('amod', 'regular', 'un'), 2),
#  (('amod', 'bad', 'un'), 2),
#  (('amod', 'heavy', 'blow'), 2),
#  (('amod', 'dead', 'mother'), 2),
#  (('amod', 'strong', 'man'), 2),
#  (('amod', 'good', 'training'), 2),
#  (('amod', 'old', 'pauper'), 2),
#  (('amod', 'ashy', 'paleness'), 2),
#  (('amod', 'full', 'height'), 2),
#  (('amod', 'back', 'kitchen'), 2),
#  (('amod', 'such', 'tears'), 2),
#  (('amod', 'kind', 'faces'), 2),
#  (('amod', 'young', 'child'), 2),
#  (('amod', 'high', 'road'), 2),
#  (('amod', 'old', 'men'), 2),
#  (('amod', 'very', 'place'), 2),
#  (('amod', 'other', 'shoulder'), 2),
#  (('amod', 'small', 'loaf'), 2),
#  (('amod', 'young', 'dog'), 2),
#  (('amod', 'possible', 'expedition'), 2),
#  (('amod', 'many', 'hours'), 2),
#  (('amod', 'such', 'words'), 2),
#  (('amod', 'little', 'heed'), 2),
#  (('amod', 'steady', 'look'), 2),
#  (('amod', 'little', 'eyes'), 2),
#  (('amod', 'sharp', 'eyes'), 2),
#  (('amod', 'young', 'gentlman'), 2),
#  (('amod', 'elderly', 'gentleman'), 2),
#  (('amod', 'vast', 'deal'), 2),
#  (('amod', 'drunken', 'men'), 2),
#  (('amod', 'feeble', 'candle'), 2),
#  (('amod', 't’other', 'one'), 2),
#  (('amod', 'much', 'difficulty'), 2),
#  (('amod', 'back', 'room'), 2),
#  (('amod', 'red', 'hair'), 2),
#  (('amod', 'OLD', 'GENTLEMAN'), 2),
#  (('amod', 'long', 'sleep'), 2),
#  (('amod', 'drowsy', 'state'), 2),
#  (('amod', 'small', 'box'), 2),
#  (('amod', 'Clever', 'dogs'), 2),
#  (('amod', 'Fine', 'fellows'), 2),
#  (('amod', 'more', 'dozen'), 2),
#  (('amod', 'fine', 'thing'), 2),
#  (('amod', 'bright', 'eyes'), 2),
#  (('amod', 'dark', 'eyes'), 2),
#  (('amod', 'brave', 'boy'), 2),
#  (('amod', 'dirty', 'place'), 2),
#  (('amod', 'great', 'man'), 2),
#  (('amod', 'fresh', 'air'), 2),
#  (('amod', 'great', 'vehemence'), 2),
#  (('amod', 'greatest', 'caution'), 2),
#  (('amod', 'only', 'person'), 2),
#  (('amod', 'good', 'un'), 2),
#  (('amod', 'young', 'devil'), 2),
#  (('amod', 'low', 'archway'), 2),
#  (('amod', 'back', 'way'), 2),
#  (('amod', 'stout', 'man'), 2),
#  (('amod', 'absent', 'gentleman'), 2),
#  (('amod', 'great', 'quantity'), 2),
#  (('amod', 'respectable', 'person'), 2),
#  (('amod', 'safe', 'one'), 2),
#  (('amod', 'right', 'moment'), 2),
#  (('amod', 'great', 'energy'), 2),
#  (('amod', 'good', 'name'), 2),
#  (('amod', 'ill', 'grace'), 2),
#  (('amod', 'Poor', 'boy'), 2),
#  (('amod', 'same', 'ground'), 2),
#  (('amod', 'feeble', 'voice'), 2),
#  (('amod', 'gold', 'watch'), 2),
#  (('amod', 'clever', 'man'), 2),
#  (('amod', 'dry', 'toast'), 2),
#  (('amod', 'easy', 'chair'), 2),
#  (('amod', 'Good', 'boy'), 2),
#  (('amod', 'strong', 'emphasis'), 2),
#  (('amod', 'young', 'pupils'), 2),
#  (('amod', 'accomplished', 'friend'), 2),
#  (('amod', 'young', 'gentlemen'), 2),
#  (('amod', 'narrow', 'streets'), 2),
#  (('amod', 'thoughtful', 'countenance'), 2),
#  (('amod', 'safe', 'side'), 2),
#  (('amod', 'big', 'coat'), 2),
#  (('amod', 'more', 'agility'), 2),
#  (('amod', 'deep', 'voice'), 2),
#  (('amod', 'built', 'fellow'), 2),
#  (('amod', 'velveteen', 'coat'), 2),
#  (('amod', 'old', 'fence'), 2),
#  (('amod', 'merry', 'heart'), 2),
#  (('amod', 'such', 'alterations'), 2),
#  (('amod', 'lower', 'tone'), 2),
#  (('amod', 'agreeable', 'friend'), 2),
#  (('amod', 'dear', 'brother'), 2),
#  (('amod', 'dear', 'boy'), 2),
#  (('amod', 'young', 'friends'), 2),
#  (('amod', 'gentle', 'voice'), 2),
#  (('amod', 'next', 'cell'), 2),
#  (('amod', 'good', 'morning'), 2),
#  (('amod', 'new', 'pair'), 2),
#  (('amod', 'old', 'clothes'), 2),
#  (('amod', 'possible', 'danger'), 2),
#  (('amod', 'heavy', 'ones'), 2),
#  (('amod', 'earnest', 'manner'), 2),
#  (('amod', 'blue', 'coat'), 2),
#  (('amod', 'white', 'hat'), 2),
#  (('amod', 'inmost', 'recesses'), 2),
#  (('amod', 'previous', 'history'), 2),
#  (('amod', 'full', 'account'), 2),
#  (('amod', 'small', 'parcel'), 2),
#  (('amod', 'many', 'injunctions'), 2),
#  (('amod', 'sweet', 'face'), 2),
#  (('amod', 'old', 'friends'), 2),
#  (('amod', 'hearty', 'shake'), 2),
#  (('amod', 'born', 'devil'), 2),
#  (('amod', 'harsh', 'voice'), 2),
#  (('amod', 'mutual', 'interest'), 2),
#  (('amod', 'much', 'importance'), 2),
#  (('amod', 'dark', 'passage'), 2),
#  (('amod', 'incoherent', 'exclamations'), 2),
#  (('amod', 'poor', 'mother'), 2),
#  (('amod', 'recent', 'illness'), 2),
#  (('amod', 'dark', 'corner'), 2),
#  (('amod', 'same', 'position'), 2),
#  (('amod', 'old', 'un'), 2),
#  (('amod', 'good', 'gentleman'), 2),
#  (('amod', 'old', 'house'), 2),
#  (('amod', 'further', 'end'), 2),
#  (('amod', 'visible', 'effect'), 2),
#  (('amod', 'old', 'wretch'), 2),
#  (('amod', 'civil', 'words'), 2),
#  (('amod', 'Civil', 'words'), 2),
#  (('amod', 'sudden', 'shiftings'), 2),
#  (('amod', 'full', 'bloom'), 2),
#  (('amod', 'porochial', 'life'), 2),
#  (('amod', 'great', 'propriety'), 2),
#  (('amod', 'low', 'state'), 2),
#  (('amod', 'dear', 'love'), 2),
#  (('amod', 'due', 'course'), 2),
#  (('amod', 'hot', 'gin'), 2),
#  (('amod', 'porochial', 'beadle'), 2),
#  (('amod', 'attentive', 'perusal'), 2),
#  (('amod', 'little', 'history'), 2),
#  (('amod', 'good', 'friends'), 2),
#  (('amod', 'general', 'nature'), 2),
#  (('amod', 'searching', 'look'), 2),
#  (('amod', 'trembling', 'limbs'), 2),
#  (('amod', 'rusty', 'bars'), 2),
#  (('amod', 'named', 'gentleman'), 2),
#  (('amod', 'same', 'thing'), 2),
#  (('amod', 'other', 'times'), 2),
#  (('amod', 'retreating', 'footsteps'), 2),
#  (('amod', 'hideous', 'man'), 2),
#  (('amod', 'farther', 'end'), 2),
#  (('amod', 'furnished', 'apartment'), 2),
#  (('amod', 'hoarse', 'whisper'), 2),
#  (('amod', 'shrill', 'chuckle'), 2),
#  (('amod', 'prostrate', 'form'), 2),
#  (('amod', 'little', 'thing'), 2),
#  (('amod', 'dirty', 'room'), 2),
#  (('amod', 'helpless', 'state'), 2),
#  (('amod', 'full', 'speed'), 2),
#  (('amod', 'other', 'things'), 2),
#  (('amod', 'active', 'service'), 2),
#  (('amod', 'great', 'precipitation'), 2),
#  (('amod', 'cold', 'meat'), 2),
#  (('amod', 'great', 'disdain'), 2),
#  (('amod', 'hind', 'legs'), 2),
#  (('amod', 'great', 'speed'), 2),
#  (('amod', 'gloomy', 'lanes'), 2),
#  (('amod', 'same', 'voice'), 2),
#  (('amod', 'smoky', 'fire'), 2),
#  (('amod', 'old', 'couch'), 2),
#  (('amod', 'great', 'coats'), 2),
#  (('amod', 'detached', 'house'), 2),
#  (('amod', 'cold', 'sweat'), 2),
#  (('amod', 'little', 'window'), 2),
#  (('amod', 'dark', 'lantern'), 2),
#  (('amod', 'same', 'whisper'), 2),
#  (('amod', 'sharp', 'wind'), 2),
#  (('amod', 'round', 'table'), 2),
#  (('amod', 'soft', 'tap'), 2),
#  (('amod', 'little', 'finger'), 2),
#  (('amod', 'great', 'men'), 2),
#  (('amod', 'strong', 'men'), 2),
#  (('amod', 'much', 'gravity'), 2),
#  (('amod', 'early', 'life'), 2),
#  (('amod', 'many', 'corpses'), 2),
#  (('amod', 'hollow', 'voice'), 2),
#  (('amod', 'very', 'room'), 2),
#  (('amod', 'violent', 'effort'), 2),
#  (('amod', 'great', 'interest'), 2),
#  (('amod', 'similar', 'kind'), 2),
#  (('amod', 'fine', 'girl'), 2),
#  (('amod', 'second', 'hand'), 2),
#  (('amod', 'remote', 'corner'), 2),
#  (('amod', 'former', 'attitude'), 2),
#  (('amod', 'various', 'exclamations'), 2),
#  (('amod', 'fresh', 'gust'), 2),
#  (('amod', 'few', 'steps'), 2),
#  (('amod', 'own', 'accord'), 2),
#  (('amod', 'lighted', 'candle'), 2),
#  (('amod', 'profound', 'silence'), 2),
#  (('amod', 'weak', 'creeturs'), 2),
#  (('amod', 'long', 'embrace'), 2),
#  (('amod', 'shorter', 'man'), 2),
#  (('amod', 'third', 'man'), 2),
#  (('amod', 'sudden', 'change'), 2),
#  (('amod', 'precise', 'moment'), 2),
#  (('amod', 'low', 'cry'), 2),
#  (('amod', 'previous', 'day'), 2),
#  (('amod', 'open', 'fields'), 2),
#  (('amod', 'dead', 'men'), 2),
#  (('amod', 'ingenious', 'gentleman'), 2),
#  (('amod', 'broken', 'limb'), 2),
#  (('amod', 'old', 'servant'), 2),
#  (('amod', 'full', 'suit'), 2),
#  (('amod', 'young', 'companion'), 2),
#  (('amod', 'younger', 'lady'), 2),
#  (('amod', 'slow', 'boy'), 2),
#  (('amod', 'many', 'assurances'), 2),
#  (('amod', 'disengaged', 'hand'), 2),
#  (('amod', 'dear', 'aunt'), 2),
#  (('amod', 'sick', 'child'), 2),
#  (('amod', 'other', 'way'), 2),
#  (('amod', 'same', 'moment'), 2),
#  (('amod', 'portly', 'man'), 2),
#  (('amod', 'whole', 'history'), 2),
#  (('amod', 'put', 'thing'), 2),
#  (('amod', 'black', 'patch'), 2),
#  (('amod', 'suspicious', 'circumstances'), 2),
#  (('amod', 'slow', 'degrees'), 2),
#  (('amod', 'quiet', 'place'), 2),
#  (('amod', 'dear', 'nurse'), 2),
#  (('amod', 'old', 'nurse'), 2),
#  (('amod', 'white', 'house'), 2),
#  (('amod', 'few', 'hours'), 2),
#  (('amod', 'happy', 'time'), 2),
#  (('amod', 'little', 'church'), 2),
#  (('amod', 'green', 'leaves'), 2),
#  (('amod', 'little', 'cottage'), 2),
#  (('amod', 'dear', 'girl'), 2),
#  (('amod', 'anxious', 'night'), 2),
#  (('amod', 'much', 'deliberation'), 2),
#  (('amod', 'great', 'hurry'), 2),
#  (('amod', 'lost', 'time'), 2),
#  (('amod', 'fair', 'creature'), 2),
#  (('amod', 'white', 'nightcap'), 2),
#  (('amod', 'own', 'bosom'), 2),
#  (('amod', 'last', 'days'), 2),
#  (('amod', 'sweet', 'girl'), 2),
#  (('amod', 'gentle', 'girl'), 2),
#  (('amod', 'very', 'force'), 2),
#  (('amod', 'same', 'reason'), 2),
#  (('amod', 'same', 'man'), 2),
#  (('amod', 'own', 'words'), 2),
#  (('amod', 'old', 'hopes'), 2),
#  (('amod', 'great', 'nobs'), 2),
#  (('amod', 'short', 'dialogue'), 2),
#  (('amod', 'sickly', 'rays'), 2),
#  (('amod', 'much', 'ease'), 2),
#  (('amod', 'same', 'eye'), 2),
#  (('amod', 'own', 'interest'), 2),
#  (('amod', 'last', 'winter'), 2),
#  (('amod', 'better', 'half'), 2),
#  (('amod', 'dense', 'mass'), 2),
#  (('amod', 'doubtful', 'character'), 2),
#  (('amod', 'second', 'story'), 2),
#  (('amod', 'little', 'rousing'), 2),
#  (('amod', 'quivering', 'lip'), 2),
#  (('amod', 'little', 'locket'), 2),
#  (('amod', 'little', 'packet'), 2),
#  (('amod', 'other', 'question'), 2),
#  (('amod', 'former', 'position'), 2),
#  (('amod', 'great', 'alacrity'), 2),
#  (('amod', 'last', 'chapter'), 2),
#  (('amod', 'low', 'growl'), 2),
#  (('amod', 'other', 'time'), 2),
#  (('amod', 'desired', 'effect'), 2),
#  (('amod', 'venerable', 'friend'), 2),
#  (('amod', 'evil', 'wind'), 2),
#  (('amod', 'more', 'notice'), 2),
#  (('amod', 'other', 'fortnight'), 2),
#  (('amod', 'clever', 'fellow'), 2),
#  (('amod', 'good', 'society'), 2),
#  (('amod', 'young', 'people'), 2),
#  (('amod', 'last', 'words'), 2),
#  (('amod', 'many', 'oaths'), 2),
#  (('amod', 'heavy', 'hand'), 2),
#  (('amod', 'brilliant', 'light'), 2),
#  (('amod', 'first', 'word'), 2),
#  (('amod', 'low', 'haunts'), 2),
#  (('amod', 'many', 'traces'), 2),
#  (('amod', 'only', 'proofs'), 2),
#  (('amod', 'old', 'hag'), 2),
#  (('amod', 'good', 'profit'), 2),
#  (('amod', 'sweet', 'lady'), 2),
#  (('amod', 'first', 'day'), 2),
#  (('amod', 'first', 'impulse'), 2),
#  (('amod', 'violent', 'agitation'), 2),
#  (('amod', 'upper', 'room'), 2),
#  (('amod', 'green', 'coat'), 2),
#  (('amod', 'stiff', 'bow'), 2),
#  (('amod', 'dear', 'friend'), 2),
#  (('amod', 'noble', 'nature'), 2),
#  (('amod', 'rigid', 'face'), 2),
#  (('amod', 'former', 'associates'), 2),
#  (('amod', 'great', 'happiness'), 2),
#  (('amod', 'long', 'while'), 2),
#  (('amod', 'worthy', 'doctor'), 2),
#  (('amod', 'whole', 'days'), 2),
#  (('amod', 'pretty', 'thing'), 2),
#  (('amod', 'silver', 'box'), 2),
#  (('amod', 'little', 'affair'), 2),
#  (('amod', 'dark', 'ways'), 2),
#  (('amod', 'strong', 'resemblance'), 2),
#  (('amod', 'new', 'associate'), 2),
#  (('amod', 'bad', 'life'), 2),
#  (('amod', 'little', 'child'), 2),
#  (('amod', 'foreign', 'country'), 2),
#  (('amod', 'old', 'haunt'), 2),
#  (('amod', 'old', 'life'), 2),
#  (('amod', 'bitter', 'tears'), 2),
#  (('amod', 'own', 'fancy'), 2),
#  (('amod', 'assumed', 'name'), 2),
#  (('amod', 'own', 'door'), 2),
#  (('amod', 'folded', 'hands'), 2),
#  (('amod', 'ghastly', 'figure'), 2),
#  (('amod', 'murdered', 'woman'), 2),
#  (('amod', 'ere', 'bag'), 2),
#  (('amod', 'oldest', 'friend'), 2),
#  (('amod', 'whole', 'property'), 2),
#  (('amod', 'dead', 'man'), 2),
#  (('amod', 'own', 'father'), 2),
#  (('amod', 'wretched', 'man'), 2),
#  (('amod', 'gloomy', 'passage'), 2),
#  (('amod', 'young', 'clergyman'), 2),
#  (('amod', 'PUBLIC', 'LIFE'), 1),
#  (('amod', 'FIRST', 'TIME'), 1),
#  (('amod', 'HOPEFUL', 'PUPILS'), 1),
#  (('amod', 'SHORT', 'CHAPTER'), 1),
#  (('amod', 'SLIGHT', 'SPECIMEN'), 1),
#  (('amod', 'YOUTHFUL', 'FRIENDS'), 1),
#  (('amod', 'REPUTABLE', 'FRIENDS'), 1),
#  (('amod', 'MANY', 'THINGS'), 1),
#  (('amod', 'SHORT', 'ONE'), 1),
#  (('amod', 'UNCOMMON', 'CONTRAST'), 1),
#  (('amod', 'FATAL', 'CONSEQUENCES'), 1),
#  (('amod', 'other', 'buildings'), 1),
#  (('amod', 'public', 'buildings'), 1),
#  (('amod', 'certain', 'town'), 1),
#  (('amod', 'fictitious', 'name'), 1),
#  (('amod', 'most', 'towns'), 1),
#  (('amod', 'possible', 'consequence'), 1),
#  (('amod', 'inestimable', 'merit'), 1),
#  (('amod', 'concise', 'specimen'), 1),
#  (('amod', 'extant', 'specimen'), 1),
#  (('amod', 'fortunate', 'circumstance'), 1),
#  (('amod', 'human', 'being'), 1),
#  (('amod', 'troublesome', 'practice'), 1),
#  (('amod', 'easy', 'existence'), 1),
#  (('amod', 'little', 'mattress'), 1),
#  (('amod', 'brief', 'period'), 1),
#  (('amod', 'anxious', 'aunts'), 1),
#  (('amod', 'experienced', 'nurses'), 1),
#  (('amod', 'profound', 'wisdom'), 1),
#  (('amod', 'unwonted', 'allowance'), 1),
#  (('amod', 'few', 'struggles'), 1),
#  (('amod', 'new', 'burden'), 1),
#  (('amod', 'male', 'infant'), 1),
#  (('amod', 'useful', 'appendage'), 1),
#  (('amod', 'free', 'action'), 1),
#  (('amod', 'more', 'kindness'), 1),
#  (('amod', 'dear', 'lamb'), 1),
#  (('amod', 'young', 'lamb'), 1),
#  (('amod', 'consolatory', 'perspective'), 1),
#  (('amod', 'due', 'effect'), 1),
#  (('amod', 'cold', 'lips'), 1),
#  (('amod', 'white', 'lips'), 1),
#  (('amod', 'great', 'deliberation'), 1),
#  (('amod', 'little', 'gruel'), 1),
#  (('amod', 'looking', 'girl'), 1),
#  (('amod', 'medical', 'gentleman'), 1),
#  (('amod', 'low', 'chair'), 1),
#  (('amod', 'excellent', 'example'), 1),
#  (('amod', 'haughtiest', 'stranger'), 1),
#  (('amod', 'proper', 'station'), 1),
#  (('amod', 'humble', 'drudge'), 1),
#  (('amod', 'starved', 'drudge'), 1),
#  (('amod', 'tender', 'mercies'), 1),
#  (('amod', 'next', 'months'), 1),
#  (('amod', 'hungry', 'situation'), 1),
#  (('amod', 'other', 'offenders'), 1),
#  (('amod', 'juvenile', 'offenders'), 1),
#  (('amod', 'much', 'clothing'), 1),
#  (('amod', 'small', 'head'), 1),
#  (('amod', 'good', 'diet'), 1),
#  (('amod', 'enough', 'halfpenny'), 1),
#  (('amod', 'accurate', 'perception'), 1),
#  (('amod', 'weekly', 'stipend'), 1),
#  (('amod', 'rising', 'generation'), 1),
#  (('amod', 'parochial', 'generation'), 1),
#  (('amod', 'great', 'theory'), 1),
#  (('amod', 'own', 'horse'), 1),
#  (('amod', 'rampacious', 'animal'), 1),
#  (('amod', 'experimental', 'philosophy'), 1),
#  (('amod', 'protecting', 'care'), 1),
#  (('amod', 'similar', 'result'), 1),
#  (('amod', 'possible', 'portion'), 1),
#  (('amod', 'weakest', 'food'), 1),
#  (('amod', 'possible', 'food'), 1),
#  (('amod', 'miserable', 'being'), 1),
#  (('amod', 'interesting', 'inquest'), 1),
#  (('amod', 'latter', 'accident'), 1),
#  (('amod', 'rare', 'occurrence'), 1),
#  (('amod', 'troublesome', 'questions'), 1),
#  (('amod', 'periodical', 'pilgrimages'), 1),
#  (('amod', 'extraordinary', 'crop'), 1),
#  (('amod', 'ninth', 'birthday'), 1),
#  (('amod', 'pale', 'child'), 1),
#  (('amod', 'thin', 'child'), 1),
#  (('amod', 'good', 'spirit'), 1),
#  (('amod', 'sturdy', 'spirit'), 1),
#  (('amod', 'spare', 'diet'), 1),
#  (('amod', 'select', 'party'), 1),
#  (('amod', 'affected', 'ecstasies'), 1),
#  (('amod', 'hearted', 'salutation'), 1),
#  (('amod', 'kindred', 'spirit'), 1),
#  (('amod', 'little', 'wicket'), 1),
#  (('amod', 'tremendous', 'shake'), 1),
#  (('amod', 'respectful', 'conduct'), 1),
#  (('amod', 'porochial', 'business'), 1),
#  (('amod', 'porochial', 'orphans'), 1),
#  (('amod', 'porochial', 'delegate'), 1),
#  (('amod', 'great', 'humility'), 1),
#  (('amod', 'great', 'idea'), 1),
#  (('amod', 'oratorical', 'powers'), 1),
#  (('amod', 'calmer', 'tone'), 1),
#  (('amod', 'small', 'parlour'), 1),
#  (('amod', 'captivating', 'sweetness'), 1),
#  (('amod', 'long', 'walk'), 1),
#  (('amod', 'placid', 'manner'), 1),
#  (('amod', 'little', 'water'), 1),
#  (('amod', 'blessed', 'infants'), 1),
#  (('amod', 'interesting', 'process'), 1),
#  (('amod', 'very', 'eyes'), 1),
#  (('amod', 'left', 'eye'), 1),
#  (('amod', 'offered', 'reward'), 1),
#  (('amod', 'superlative', 'exertions'), 1),
#  (('amod', 'supernat’ral', 'exertions'), 1),
#  (('amod', 'great', 'pride'), 1),
#  (('amod', 'alphabetical', 'order'), 1),
#  (('amod', 'next', 'one'), 1),
#  (('amod', 'literary', 'character'), 1),
#  (('amod', 'furious', 'countenance'), 1),
#  (('amod', 'great', 'consolation'), 1),
#  (('amod', 'enough', 'sense'), 1),
#  (('amod', 'great', 'regret'), 1),
#  (('amod', 'difficult', 'matter'), 1),
#  (('amod', 'recent', 'usage'), 1),
#  (('amod', 'great', 'assistants'), 1),
#  (('amod', 'brown', 'cloth'), 1),
#  (('amod', 'wretched', 'home'), 1),
#  (('amod', 'kind', 'word'), 1),
#  (('amod', 'childish', 'grief'), 1),
#  (('amod', 'little', 'companions'), 1),
#  (('amod', 'only', 'friends'), 1),
#  (('amod', 'great', 'world'), 1),
#  (('amod', 'wide', 'world'), 1),
#  (('amod', 'long', 'strides'), 1),
#  (('amod', 'laced', 'cuff'), 1),
#  (('amod', 'brief', 'replies'), 1),
#  (('amod', 'temporary', 'blandness'), 1),
#  (('amod', 'second', 'slice'), 1),
#  (('amod', 'defined', 'notion'), 1),
#  (('amod', 'live', 'board'), 1),
#  (('amod', 'fat', 'gentlemen'), 1),
#  (('amod', 'higher', 'chair'), 1),
#  (('amod', 'red', 'face'), 1),
#  (('amod', 'capital', 'way'), 1),
#  (('amod', 'useful', 'trade'), 1),
#  (('amod', 'faced', 'gentleman'), 1),
#  (('amod', 'simple', 'process'), 1),
#  (('amod', 'large', 'ward'), 1),
#  (('amod', 'rough', 'bed'), 1),
#  (('amod', 'hard', 'bed'), 1),
#  (('amod', 'novel', 'illustration'), 1),
#  (('amod', 'tender', 'laws'), 1),
#  (('amod', 'very', 'day'), 1),
#  (('amod', 'material', 'influence'), 1),
#  (('amod', 'future', 'fortunes'), 1),
#  (('amod', 'very', 'men'), 1),
#  (('amod', 'sage', 'men'), 1),
#  (('amod', 'deep', 'men'), 1),
#  (('amod', 'philosophical', 'men'), 1),
#  (('amod', 'ordinary', 'folks'), 1),
#  (('amod', 'regular', 'place'), 1),
#  (('amod', 'public', 'entertainment'), 1),
#  (('amod', 'gradual', 'process'), 1),
#  (('amod', 'unlimited', 'supply'), 1),
#  (('amod', 'small', 'quantities'), 1),
#  (('amod', 'thin', 'gruel'), 1),
#  (('amod', 'married', 'people'), 1),
#  (('amod', 'great', 'expense'), 1),
#  (('amod', 'many', 'applicants'), 1),
#  (('amod', 'last', 'heads'), 1),
#  (('amod', 'headed', 'men'), 1),
#  (('amod', 'first', 'months'), 1),
#  (('amod', 'full', 'operation'), 1),
#  (('amod', 'wasted', 'forms'), 1),
#  (('amod', 'shrunken', 'forms'), 1),
#  (('amod', 'large', 'hall'), 1),
#  (('amod', 'festive', 'composition'), 1),
#  (('amod', 'great', 'rejoicing'), 1),
#  (('amod', 'public', 'rejoicing'), 1),
#  (('amod', 'very', 'bricks'), 1),
#  (('amod', 'stray', 'splashes'), 1),
#  (('amod', 'slow', 'starvation'), 1),
#  (('amod', 'wild', 'boy'), 1),
#  (('amod', 'weakly', 'youth'), 1),
#  (('amod', 'tender', 'age'), 1),
#  (('amod', 'wild', 'eye'), 1),
#  (('amod', 'hungry', 'eye'), 1),
#  (('amod', 'short', 'commons'), 1),
#  (('amod', 'next', 'neighbors'), 1),
#  (('amod', 'own', 'temerity'), 1),
#  (('amod', 'healthy', 'man'), 1),
#  (('amod', 'stupefied', 'astonishment'), 1),
#  (('amod', 'small', 'rebel'), 1),
#  (('amod', 'solemn', 'conclave'), 1),
#  (('amod', 'general', 'start'), 1),
#  (('amod', 'prophetic', 'gentleman'), 1),
#  (('amod', 'instant', 'confinement'), 1),
#  (('amod', 'violent', 'termination'), 1),
#  (('amod', 'impious', 'offence'), 1),
#  (('amod', 'close', 'prisoner'), 1),
#  (('amod', 'solitary', 'room'), 1),
#  (('amod', 'becoming', 'feeling'), 1),
#  (('amod', 'prophetic', 'character'), 1),
#  (('amod', 'future', 'times'), 1),
#  (('amod', 'express', 'order'), 1),
#  (('amod', 'long', 'night'), 1),
#  (('amod', 'little', 'hands'), 1),
#  (('amod', 'hard', 'surface'), 1),
#  (('amod', 'solitary', 'incarceration'), 1),
#  (('amod', 'nice', 'weather'), 1),
#  (('amod', 'cold', 'weather'), 1),
#  (('amod', 'tingling', 'sensation'), 1),
#  (('amod', 'public', 'warning'), 1),
#  (('amod', 'religious', 'consolation'), 1),
#  (('amod', 'same', 'apartment'), 1),
#  (('amod', 'general', 'supplication'), 1),
#  (('amod', 'exclusive', 'patronage'), 1),
#  (('amod', 'comfortable', 'state'), 1),
#  (('amod', 'certain', 'arrears'), 1),
#  (('amod', 'sanguine', 'estimate'), 1),
#  (('amod', 'full', 'pounds'), 1),
#  (('amod', 'desired', 'amount'), 1),
#  (('amod', 'arithmetical', 'desperation'), 1),
#  (('amod', 'profound', 'abstraction'), 1),
#  (('amod', 'little', 'cart'), 1),
#  (('amod', 'fierce', 'imprecation'), 1),
#  (('amod', 'gentle', 'reminder'), 1),
#  (('amod', 'little', 'dispute'), 1),
#  (('amod', 'nice', 'pattern'), 1),
#  (('amod', 'small', 'pattern'), 1),
#  (('amod', 'condescending', 'smile'), 1),
#  (('amod', 'right', 'trade'), 1),
#  (('amod', 'pleasant', 'trade'), 1),
#  (('amod', 'good', 'bisness'), 1),
#  (('amod', 'spectable', 'bisness'), 1),
#  (('amod', 'sweepin', 'bisness'), 1),
#  (('amod', 'nasty', 'trade'), 1),
#  (('amod', 'Young', 'boys'), 1),
#  (('amod', 'low', 'tone'), 1),
#  (('amod', 'printed', 'report'), 1),
#  (('amod', 'great', 'emphasis'), 1),
#  (('amod', 'other', 'members'), 1),
#  (('amod', 'slight', 'imputation'), 1),
#  (('amod', 'unaccountable', 'freak'), 1),
#  (('amod', 'extraneous', 'circumstance'), 1),
#  (('amod', 'general', 'mode'), 1),
#  (('amod', 'particular', 'wish'), 1),
#  (('amod', 'nasty', 'business'), 1),
#  (('amod', 'quick', 'step'), 1),
#  (('amod', 'more', 'farthing'), 1),
#  (('amod', 'firm', 'reply'), 1),
#  (('amod', 'arch', 'look'), 1),
#  (('amod', 'very', 'afternoon'), 1),
#  (('amod', 'own', 'hands'), 1),
#  (('amod', 'tremendous', 'sight'), 1),
#  (('amod', 'useful', 'purpose'), 1),
#  (('amod', 'impressive', 'pomposity'), 1),
#  (('amod', 'many', 'parents'), 1),
#  (('amod', 'naughty', 'orphan'), 1),
#  (('amod', 'awful', 'voice'), 1),
#  (('amod', 'foolish', 'action'), 1),
#  (('amod', 'enough', 'water'), 1),
#  (('amod', 'gentle', 'hint'), 1),
#  (('amod', 'palpitating', 'heart'), 1),
#  (('amod', 'grim', 'look'), 1),
#  (('amod', 'contradictory', 'style'), 1),
#  (('amod', 'large', 'room'), 1),
#  (('amod', 'powdered', 'heads'), 1),
#  (('amod', 'washed', 'face'), 1),
#  (('amod', 'looking', 'men'), 1),
#  (('amod', 'mentioned', 'gentleman'), 1),
#  (('amod', 'best', 'obeisance'), 1),
#  (('amod', 'white', 'stuff'), 1),
#  (('amod', 'other', 'trade'), 1),
#  (('amod', 'rough', 'speaker'), 1),
#  (('amod', 'regular', 'receipt'), 1),
#  (('amod', 'stamped', 'receipt'), 1),
#  (('amod', 'ugly', 'leer'), 1),
#  (('amod', 'critical', 'moment'), 1),
#  (('amod', 'terrified', 'face'), 1),
#  (('amod', 'repulsive', 'countenance'), 1),
#  (('amod', 'mingled', 'expression'), 1),
#  (('amod', 'blind', 'magistrate'), 1),
#  (('amod', 'unconcerned', 'aspect'), 1),
#  (('amod', 'other', 'magistrate'), 1),
#  (('amod', 'dreadful', 'man'), 1),
#  (('amod', 'impressive', 'solemnity'), 1),
#  (('amod', 'artful', 'orphans'), 1),
#  (('amod', 'moral', 'revolution'), 1),
#  (('amod', 'unsupported', 'testimony'), 1),
#  (('amod', 'same', 'evening'), 1),
#  (('amod', 'gloomy', 'mystery'), 1),
#  (('amod', 'most', 'matters'), 1),
#  (('amod', 'opposite', 'description'), 1),
#  (('amod', 'great', 'families'), 1),
#  (('amod', 'advantageous', 'place'), 1),
#  (('amod', 'general', 'custom'), 1),
#  (('amod', 'wise', 'example'), 1),
#  (('amod', 'small', 'vessel'), 1),
#  (('amod', 'good', 'port'), 1),
#  (('amod', 'unhealthy', 'port'), 1),
#  (('amod', 'playful', 'mood'), 1),
#  (('amod', 'known', 'recreations'), 1),
#  (('amod', 'favourite', 'recreations'), 1),
#  (('amod', 'various', 'inquiries'), 1),
#  (('amod', 'preliminary', 'inquiries'), 1),
#  (('amod', 'less', 'person'), 1),
#  (('amod', 'parochial', 'undertaker'), 1),
#  (('amod', 'gaunt', 'man'), 1),
#  (('amod', 'jointed', 'man'), 1),
#  (('amod', 'threadbare', 'black'), 1),
#  (('amod', 'same', 'colour'), 1),
#  (('amod', 'smiling', 'aspect'), 1),
#  (('amod', 'proffered', 'box'), 1),
#  (('amod', 'ingenious', 'model'), 1),
#  (('amod', 'little', 'model'), 1),
#  (('amod', 'friendly', 'manner'), 1),
#  (('amod', 'great', 'official'), 1),
#  (('amod', 'new', 'system'), 1),
#  (('amod', 'seasoned', 'timber'), 1),
#  (('amod', 'expensive', 'article'), 1),
#  (('amod', 'particular', 'article'), 1),
#  (('amod', 'great', 'disadvantage'), 1),
#  (('amod', 'stout', 'people'), 1),
#  (('amod', 'great', 'hole'), 1),
#  (('amod', 'becoming', 'indignation'), 1),
#  (('amod', 'used', 'man'), 1),
#  (('amod', 'porochial', 'prentis'), 1),
#  (('amod', 'dead', 'weight'), 1),
#  (('amod', 'porochial', 'throat'), 1),
#  (('amod', 'Liberal', 'terms'), 1),
#  (('amod', 'liberal', 'terms'), 1),
#  (('amod', 'distinct', 'raps'), 1),
#  (('amod', 'Roman', 'capitals'), 1),
#  (('amod', 'gigantic', 'size'), 1),
#  (('amod', 'official', 'coat'), 1),
#  (('amod', 'elegant', 'button'), 1),
#  (('amod', 'porochial', 'seal'), 1),
#  (('amod', 'reduced', 'tradesman'), 1),
#  (('amod', 'common', 'necessaries'), 1),
#  (('amod', 'special', 'verdict'), 1),
#  (('amod', 'relieving', 'officer'), 1),
#  (('amod', 'ignorant', 'jurymen'), 1),
#  (('amod', 'more', 'philosophy'), 1),
#  (('amod', 'political', 'economy'), 1),
#  (('amod', 'independent', 'sort'), 1),
#  (('amod', 'rising', 'wrath'), 1),
#  (('amod', 'indignant', 'officer'), 1),
#  (('amod', 'calmer', 'voice'), 1),
#  (('amod', 'short', 'trial'), 1),
#  (('amod', 'enough', 'work'), 1),
#  (('amod', 'little', 'emotion'), 1),
#  (('amod', 'common', 'consent'), 1),
#  (('amod', 'great', 'state'), 1),
#  (('amod', 'virtuous', 'astonishment'), 1),
#  (('amod', 'smallest', 'tokens'), 1),
#  (('amod', 'simple', 'fact'), 1),
#  (('amod', 'little', 'feeling'), 1),
#  (('amod', 'fair', 'way'), 1),
#  (('amod', 'brutal', 'stupidity'), 1),
#  (('amod', 'perfect', 'silence'), 1),
#  (('amod', 'square', 'parcel'), 1),
#  (('amod', 'new', 'scene'), 1),
#  (('amod', 'windy', 'day'), 1),
#  ...]

# %%
def create_df(pos,ents,top_k=30):
  ents = [[x[0][0],x[0][1],x[1],'ENT'] for x in ents][:top_k]
  pos = [[x[0][0],x[0][1],x[1], 'POS'] for x in pos][:top_k]
  df = pd.concat([pd.DataFrame(pos,columns=['text','type','count','category']),pd.DataFrame(ents,columns=['text','type','count','category'])])
  df = df[(df['type']!='PUNCT')&(df['type']!='PART')&(df['type']!='SPACE')]

  return df

# %%
# df = create_df(pos,ents)
# df

# %%
def nest_df(df, threshold=2):
  pos_list = []
  ent_list = []
  df = df[(df['count']>threshold)]

  pos_cats = list(set(df[df['category']=='POS']['type']))
  ent_cats = list(set(df[df['category']=='ENT']['type']))

  for pos in pos_cats:
    pos_list.append({'name':pos,'children':[]})
  for ent in ent_cats:
    ent_list.append({'name':ent,'children':[]})

  for pos in pos_list:
    df_reduce = df[df['type']==pos['name']]
    word_collection = []
    for idx in range(len(df_reduce)):
      word_collection.append({'name':df_reduce['text'].iloc[idx], 'value':int(df_reduce['count'].iloc[idx])})
    pos['children'] = word_collection

  for ent in ent_list:
    df_reduce = df[df['type']==ent['name']]
    word_collection = []
    for idx in range(len(df_reduce)):
      word_collection.append({'name':df_reduce['text'].iloc[idx], 'value':int(df_reduce['count'].iloc[idx])})
    ent['children'] = word_collection

  return pos_list, ent_list

# %%
#nest_df(df, threshold=2)

# %%
def create_hierarchical_data(lit_df, threshold=0):
  ## PERIOD
  ## AUTHOR
  ## BOOK
  ## ENTS / POS
  ## POS Types / Ent Types
  ## Alphabetical ?
  data = {}

  periods = list(set(lit_df['period']))

  data['name'] = 'literature'
  data['children'] = []

  for period in periods:
    data['children'].append({'name':period, 'children':[]})
    
  for entry in data['children']:
    period = entry['name']
    authors = list(set(lit_df[lit_df['period']==period]['author']))
    for auth in authors:
      entry['children'].append({'name': auth, 'children':[]})

  for entry in data['children']:
    for author in entry['children']:
      books = list(set(lit_df[lit_df['author']==author['name']]['title']))
      for book in books:
        author['children'].append({'name': book, 'children':[]})

  for entry in tqdm(data['children']):
    for author in entry['children']:
      for book in author['children']:
        url = lit_df[lit_df['title']==book['name']]['url'].iloc[0]
        pos, ents = break_down_text(url)
        df = create_df(pos,ents)
        pos_types, ent_types = nest_df(df, threshold)

        book['children'].append({'name':'parts_of_speech', 'children':pos_types})
        book['children'].append({'name':'named_entities', 'children':ent_types})
        
          
  dumps = json.dumps(data, indent=4)  

  with open("/content/drive/MyDrive/NLP_2023/literature_hierarchy.json", "w") as outfile:
      outfile.write(dumps)

  return data

create_hierarchical_data(lit_df, threshold=5)
# Out:
# Streaming output truncated to the last 5000 lines.
#  21%|██▏       | 3546/16557 [10:48<45:41,  4.75it/s]
#  21%|██▏       | 3547/16557 [10:48<46:01,  4.71it/s]
#  21%|██▏       | 3548/16557 [10:48<41:27,  5.23it/s]
#  21%|██▏       | 3549/16557 [10:48<42:55,  5.05it/s]
#  21%|██▏       | 3550/16557 [10:48<44:13,  4.90it/s]
#  21%|██▏       | 3551/16557 [10:49<44:49,  4.84it/s]
#  21%|██▏       | 3552/16557 [10:49<44:59,  4.82it/s]
#  21%|██▏       | 3553/16557 [10:49<45:56,  4.72it/s]
#  21%|██▏       | 3554/16557 [10:49<46:44,  4.64it/s]
#  21%|██▏       | 3555/16557 [10:50<43:37,  4.97it/s]
#  21%|██▏       | 3556/16557 [10:50<41:53,  5.17it/s]
#  21%|██▏       | 3557/16557 [10:50<40:52,  5.30it/s]
#  21%|██▏       | 3558/16557 [10:50<40:26,  5.36it/s]
#  21%|██▏       | 3559/16557 [10:50<40:18,  5.37it/s]
#  22%|██▏       | 3560/16557 [10:50<39:16,  5.52it/s]
#  22%|██▏       | 3561/16557 [10:51<38:24,  5.64it/s]
#  22%|██▏       | 3562/16557 [10:51<34:44,  6.23it/s]
#  22%|██▏       | 3563/16557 [10:51<31:31,  6.87it/s]
#  22%|██▏       | 3564/16557 [10:51<32:53,  6.58it/s]
#  22%|██▏       | 3565/16557 [10:51<33:07,  6.54it/s]
#  22%|██▏       | 3566/16557 [10:51<33:36,  6.44it/s]
#  22%|██▏       | 3567/16557 [10:51<34:34,  6.26it/s]
#  22%|██▏       | 3568/16557 [10:52<34:42,  6.24it/s]
#  22%|██▏       | 3569/16557 [10:52<34:37,  6.25it/s]
#  22%|██▏       | 3570/16557 [10:52<34:46,  6.22it/s]
