# %%
# !python -m spacy download en_core_web_trf
# !pip install spacy
# !pip install spacy-transformers

# %%
import spacy
import spacy_transformers

# %%
import pandas as pd
import requests
from tqdm import tqdm
from collections import Counter
import json

# %%
lit_df = pd.read_csv('/content/drive/MyDrive/NLP_2023/literature.csv')
lit_df = lit_df[lit_df['author']!='William Shakespeare']
lit_df
# Out:
#              author                                        title  year  \
# 0    Jonathan Swift                            A Tale of the Tub  1704
# 1    Jonathan Swift                        The Journal to Stella  1710
# 2    Jonathan Swift            The Prose Works of Jonathan Swift  1724
# 3    Jonathan Swift                           Gulliver's Travels  1726
# 4       Jane Austen                        Sense and Sensibility  1811
# 5       Jane Austen                          Pride and Prejudice  1813
# 6       Jane Austen                               Mansfield Park  1814
# 7       Jane Austen                                         Emma  1815
# 8       Jane Austen                                   Persuasion  1818
# 9       Jane Austen                             Northanger Abbey  1818
# 10     Mary Shelley                                 Frankenstein  1818
# 11     Mary Shelley                                     Mathilda  1819
# 12     Mary Shelley                                 The Last Man  1826
# 13  Charles Dickens                                 Oliver Twist  1837
# 14  Charles Dickens                            David Copperfield  1849
# 15  Charles Dickens                                  Bleak House  1852
# 16  Charles Dickens                                   Hard Times  1854
# 17  Charles Dickens                         A Tale of Two Cities  1859
# 18  Charles Dickens                           Great Expectations  1860
# 19       Mark Twain                             Innocents Abroad  1869
# 20       Mark Twain                 The Adventures of Tom Sawyer  1876
# 21       Mark Twain                      Life on the Mississippi  1876
# 22       Mark Twain                    The Prince and The Pauper  1881
# 23       Mark Twain               Adventures of Huckleberry Finn  1884
# 24       Mark Twain  A Connecticut Yankee in King Arthur's Court  1889
# 25       Mark Twain             The Tragedy of Pudd'nhead Wilson  1894
# 26       H.G. Wells                             The Time Machine  1895
# 27       H.G. Wells                  The Island of Doctor Moreau  1896
# 28       H.G. Wells                            The Invisible Man  1897
# 29       H.G. Wells                        The War of the Worlds  1898
# 30    Joseph Conrad                            Heart of Darkness  1899
# 31    Joseph Conrad                                     Lord Jim  1900
# 32    Joseph Conrad             Nostromo: A Tale of the Seaboard  1904
# 33    Joseph Conrad                             The Secret Agent  1907
# 34    Joseph Conrad                            The Secret Sharer  1910
# 35  Agatha Christie              The Mysterious Affair at Styles  1921
# 36  Agatha Christie                         The Secret Adversary  1922
# 37  Agatha Christie                      The Murder on the Links  1923
# 38  Agatha Christie                    The Man in the Brown Suit  1924
# 39  Agatha Christie                  The Murder of Roger Ackroyd  1926
#
#                                                   url language     source  \
# 0     https://www.gutenberg.org/files/4737/4737-0.txt  English  Gutenberg
# 1     https://www.gutenberg.org/files/4208/4208-0.txt  English  Gutenberg
# 2   https://www.gutenberg.org/cache/epub/12784/pg1...  English  Gutenberg
# 3       https://www.gutenberg.org/files/829/829-0.txt  English  Gutenberg
# 4       https://www.gutenberg.org/files/161/161-0.txt  English  Gutenberg
# 5   https://www.gutenberg.org/cache/epub/1342/pg13...  English  Gutenberg
# 6   https://www.gutenberg.org/cache/epub/141/pg141...  English  Gutenberg
# 7   https://www.gutenberg.org/cache/epub/158/pg158...  English  Gutenberg
# 8   https://www.gutenberg.org/cache/epub/105/pg105...  English  Gutenberg
# 9   https://www.gutenberg.org/cache/epub/121/pg121...  English  Gutenberg
# 10   https://www.gutenberg.org/cache/epub/84/pg84.txt  English  Gutenberg
# 11  https://www.gutenberg.org/cache/epub/15238/pg1...  English  Gutenberg
# 12  https://www.gutenberg.org/cache/epub/18247/pg1...  English  Gutenberg
# 13  https://www.gutenberg.org/cache/epub/730/pg730...  English  Gutenberg
# 14  https://www.gutenberg.org/cache/epub/766/pg766...  English  Gutenberg
# 15  https://www.gutenberg.org/cache/epub/1023/pg10...  English  Gutenberg
# 16      https://www.gutenberg.org/files/786/786-0.txt  English  Gutenberg
# 17        https://www.gutenberg.org/files/98/98-0.txt  English  Gutenberg
# 18    https://www.gutenberg.org/files/1400/1400-0.txt  English  Gutenberg
# 19  https://www.gutenberg.org/cache/epub/3176/pg31...  English  Gutenberg
# 20        https://www.gutenberg.org/files/74/74-0.txt  English  Gutenberg
# 21      https://www.gutenberg.org/files/245/245-0.txt  English  Gutenberg
# 22    https://www.gutenberg.org/files/1837/1837-0.txt  English  Gutenberg
# 23        https://www.gutenberg.org/files/76/76-0.txt  English  Gutenberg
# 24   https://www.gutenberg.org/cache/epub/86/pg86.txt  English  Gutenberg
# 25      https://www.gutenberg.org/files/102/102-0.txt  English  Gutenberg
# 26        https://www.gutenberg.org/files/35/35-0.txt  English  Gutenberg
# 27  https://www.gutenberg.org/cache/epub/159/pg159...  English  Gutenberg
# 28  https://www.gutenberg.org/cache/epub/5230/pg52...  English  Gutenberg
# 29   https://www.gutenberg.org/cache/epub/36/pg36.txt  English  Gutenberg
# 30               https://www.gutenberg.org/ebooks/219  English  Gutenberg
# 31  https://www.gutenberg.org/cache/epub/5658/pg56...  English  Gutenberg
# 32    https://www.gutenberg.org/files/2021/2021-0.txt  English  Gutenberg
# 33      https://www.gutenberg.org/files/974/974-0.txt  English  Gutenberg
# 34      https://www.gutenberg.org/files/220/220-0.txt  English  Gutenberg
# 35  https://www.gutenberg.org/cache/epub/863/pg863...  English  Gutenberg
# 36  https://www.gutenberg.org/cache/epub/1155/pg11...  English  Gutenberg
# 37  https://www.gutenberg.org/cache/epub/58866/pg5...  English  Gutenberg
# 38  https://www.gutenberg.org/cache/epub/61168/pg6...  English  Gutenberg
# 39  https://www.gutenberg.org/cache/epub/69087/pg6...  English  Gutenberg
#
#                  period
# 0   Augustan literature
# 1   Augustan literature
# 2   Augustan literature
# 3   Augustan literature
# 4           Romanticism
# 5           Romanticism
# 6           Romanticism
# 7           Romanticism
# 8           Romanticism
# 9           Romanticism
# 10          Romanticism
# 11          Romanticism
# 12          Romanticism
# 13            Victorian
# 14            Victorian
# 15            Victorian
# 16            Victorian
# 17            Victorian
# 18            Victorian
# 19     American Realism
# 20     American Realism
# 21     American Realism
# 22     American Realism
# 23     American Realism
# 24     American Realism
# 25     American Realism
# 26      Proto-Modernism
# 27      Proto-Modernism
# 28      Proto-Modernism
# 29      Proto-Modernism
# 30            Modernism
# 31            Modernism
# 32            Modernism
# 33            Modernism
# 34            Modernism
# 35        Genre Fiction
# 36        Genre Fiction
# 37        Genre Fiction
# 38        Genre Fiction
# 39        Genre Fiction

# %%
nlp = spacy.load("en_core_web_trf")

# %%
def break_down_text(url):
  pos_list = []
  ent_list = []
  
  page = requests.get(url)
  clean_text = ('\r\n\r\n').join([x for x in page.text.split('\r\n\r\n') if 'gutenberg' not in x.lower()]).split('START: FULL LICENSE')[0]
  split_text = clean_text.split('\n')
  # split_text = clean_text.split('\n')[1000:2000] ## for testing 
  
  for entry in split_text:
  # for entry in tqdm(split_text):
    doc = nlp(entry)
    for token in doc:
      pos_list.append((token.text, token.pos_))
    for ent in doc.ents:
      ent_list.append((ent.text, ent.label_))
  
  counter_pos = Counter(pos_list)
  counter_ents = Counter(ent_list)

  return counter_pos.most_common(), counter_ents.most_common()

# %%
url = 'https://www.gutenberg.org/cache/epub/863/pg863.txt'

pos, ents = break_down_text(url)
# Out:
# 100%|██████████| 8533/8533 [26:37<00:00,  5.34it/s]

# %%
def create_df(pos,ents,threshold=5):
  ents = [[x[0][0],x[0][1],x[1],'ENT'] for x in ents if x[1] > threshold]#[:top_k]
  pos = [[x[0][0],x[0][1],x[1], 'POS'] for x in pos if x[1] > threshold]#[:top_k]
  df = pd.concat([pd.DataFrame(pos,columns=['text','type','count','category']),pd.DataFrame(ents,columns=['text','type','count','category'])])
  df = df[(df['type']!='PUNCT')&(df['type']!='PART')&(df['type']!='SPACE')]

  return df

# %%
df = create_df(pos,ents)
df
# Out:
#                   text    type  count category
# 3                  the     DET   2377      POS
# 6                    I    PRON   1780      POS
# 7                   of     ADP   1239      POS
# 8                    a     DET   1135      POS
# 9                  and   CCONJ   1011      POS
# ..                 ...     ...    ...      ...
# 58        Styles Court     FAC      6      ENT
# 59      Hercule Poirot  PERSON      6      ENT
# 60   Leastways Cottage     FAC      6      ENT
# 61          Inglethorp     GPE      6      ENT
# 62  Ernest Heavywether  PERSON      6      ENT
#
# [1248 rows x 4 columns]

# %%
def nest_df(df, threshold=2):
  pos_list = []
  ent_list = []
  df = df[(df['count']>threshold)]

  pos_cats = list(set(df[df['category']=='POS']['type']))
  ent_cats = list(set(df[df['category']=='ENT']['type']))

  for pos in pos_cats:
    pos_list.append({'name':pos,'children':[]})
  for ent in ent_cats:
    ent_list.append({'name':ent,'children':[]})

  for pos in pos_list:
    df_reduce = df[df['type']==pos['name']]
    word_collection = []
    for idx in range(len(df_reduce)):
      word_collection.append({'name':df_reduce['text'].iloc[idx], 'value':int(df_reduce['count'].iloc[idx])})
    pos['children'] = word_collection

  for ent in ent_list:
    df_reduce = df[df['type']==ent['name']]
    word_collection = []
    for idx in range(len(df_reduce)):
      word_collection.append({'name':df_reduce['text'].iloc[idx], 'value':int(df_reduce['count'].iloc[idx])})
    ent['children'] = word_collection

  return pos_list, ent_list

# %%
#nest_df(df, threshold=2)

# %%
def create_hierarchical_data(lit_df,period,threshold=0):
  ## PERIOD
  ## AUTHOR
  ## BOOK
  ## ENTS / POS
  ## POS Types / Ent Types
  ## Alphabetical ?
  data = {}

  periods = [period]

  data['name'] = 'literature'
  data['children'] = []

  for period in periods:
    data['children'].append({'name':period, 'children':[]})
    
  for entry in data['children']:
    period = entry['name']
    authors = list(set(lit_df[lit_df['period']==period]['author']))
    for auth in authors:
      entry['children'].append({'name': auth, 'children':[]})

  for entry in data['children']:
    for author in entry['children']:
      books = list(set(lit_df[lit_df['author']==author['name']]['title']))
      for book in books:
        author['children'].append({'name': book, 'children':[]})

  for entry in data['children']:
    for author in entry['children']:
      for book in author['children']:
        print(f"Preparing {book['name']} -- By {author['name']}")
        url = lit_df[lit_df['title']==book['name']]['url'].iloc[0]
        pos, ents = break_down_text(url)
        df = create_df(pos,ents)
        pos_types, ent_types = nest_df(df, threshold)

        book['children'].append({'name':'parts_of_speech', 'children':pos_types})
        book['children'].append({'name':'named_entities', 'children':ent_types})
        
          
  dumps = json.dumps(data, indent=4)  

  with open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{period}.json", "w") as outfile:
      outfile.write(dumps)

  return data

# %%
periods = list(set(lit_df['period']))
periods
# Out:
# ['Modernism',
#  'American Realism',
#  'Proto-Modernism',
#  'Victorian',
#  'Augustan literature',
#  'Genre Fiction',
#  'Romanticism']

# %%
for period in periods:
  create_hierarchical_data(lit_df,period,threshold=0)
# Out:
# Preparing The Murder of Roger Ackroyd -- By Agatha Christie
# Preparing The Man in the Brown Suit -- By Agatha Christie
# Preparing The Mysterious Affair at Styles -- By Agatha Christie
# Preparing The Secret Adversary -- By Agatha Christie
# Preparing The Murder on the Links -- By Agatha Christie
# Preparing A Tale of the Tub -- By Jonathan Swift
# Preparing The Journal to Stella -- By Jonathan Swift
# Preparing The Prose Works of Jonathan Swift -- By Jonathan Swift
# Preparing Gulliver's Travels -- By Jonathan Swift
# Preparing The Prince and The Pauper -- By Mark Twain
# Preparing A Connecticut Yankee in King Arthur's Court -- By Mark Twain
# Preparing Life on the Mississippi -- By Mark Twain
# Preparing The Tragedy of Pudd'nhead Wilson -- By Mark Twain
# Preparing The Adventures of Tom Sawyer -- By Mark Twain
# Preparing Adventures of Huckleberry Finn -- By Mark Twain
# Preparing Innocents Abroad -- By Mark Twain
# Preparing The Time Machine -- By H.G. Wells
# Preparing The War of the Worlds -- By H.G. Wells
# Preparing The Invisible Man -- By H.G. Wells
# Preparing The Island of Doctor Moreau -- By H.G. Wells
# Preparing David Copperfield -- By Charles Dickens
# Preparing Hard Times -- By Charles Dickens
# Preparing A Tale of Two Cities -- By Charles Dickens
# Preparing Bleak House -- By Charles Dickens
# Preparing Oliver Twist -- By Charles Dickens
# Preparing Great Expectations -- By Charles Dickens
# Preparing Heart of Darkness -- By Joseph Conrad
# Preparing Lord Jim -- By Joseph Conrad
# Preparing Nostromo: A Tale of the Seaboard -- By Joseph Conrad
# Preparing The Secret Agent -- By Joseph Conrad
# Preparing The Secret Sharer -- By Joseph Conrad
# Preparing The Last Man -- By Mary Shelley
# Preparing Frankenstein -- By Mary Shelley
# Preparing Mathilda -- By Mary Shelley
# Preparing Persuasion -- By Jane Austen
# Preparing Mansfield Park -- By Jane Austen
# Preparing Northanger Abbey -- By Jane Austen
# Preparing Sense and Sensibility -- By Jane Austen
# Preparing Emma -- By Jane Austen
# Preparing Pride and Prejudice -- By Jane Austen

# %% [markdown]
# Filtering JSON Data for Visualizations

# %%
### Set Minimum Number of Examples

def set_minimum(file, min=50):
  f = open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file}.json")
  data = json.load(f)
  new_data = data

  authors = new_data['children'][0]['children']
  for author in authors:
    for book in author['children']:
      for category in book['children']:
        for subcategory in category['children']:
          new_children = []
          for word in subcategory['children']:
            if word['value'] > min:
              new_children.append(word)
          subcategory['children'] = new_children

  dumps = json.dumps(new_data, indent=4)  

  with open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file.lower().replace(' ','_')}_min_{min}.json", "w") as outfile:
      outfile.write(dumps)


  return new_data

set_minimum('American Realism', min=5)

# %%
### Extract only Entities (with min)

f = open("/content/drive/MyDrive/NLP_2023/lit_breakdown/Romanticism.json")

data = json.load(f)

def only_entities(file, min=5):
  f = open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file}.json")
  data = json.load(f)
  new_data = data

  authors = new_data['children'][0]['children']
  for author in authors:
    for book in author['children']:
      for category in book['children']:
        for subcategory in category['children']:
          new_children = []
          for word in subcategory['children']:
            if word['value'] > min:
              new_children.append(word)
          subcategory['children'] = new_children

  authors = new_data['children'][0]['children']
  for author in authors:
    for book in author['children']:
      new_entities = []
      for category in book['children']:
        if category['name'] == 'Named Entities':
          new_entities.append(category['children'])
      if len(new_entities) == 1:
        book['children'] = new_entities[0]
      

  dumps = json.dumps(new_data, indent=4)  

  with open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file.lower().replace(' ','_')}_ents_min_{min}.json", "w") as outfile:
      outfile.write(dumps)
  return new_data
  
# only_entities('Romanticism', min=5)

# %%
## This function extracts a particular category of entity



def only_one_type_entities(file, ent='GPE', min=1):
  f = open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file}.json")

  data = json.load(f)
  new_data = data

  authors = new_data['children'][0]['children']
  for author in authors:
    for book in author['children']:
      for category in book['children']:
        for subcategory in category['children']:
          new_children = []
          for word in subcategory['children']:
            if word['value'] > min:
              new_children.append(word)
          subcategory['children'] = new_children

  # books = new_data['children'][0]['children'][1]['children']
  authors = new_data['children'][0]['children']
  for author in authors:
    for book in author['children']:
      for category in book['children']:
        new_category = []
        for subcategory in category['children']:
          if subcategory['name'] == ent:
            new_category.append(subcategory['children'])
        if len(new_category) == 1:
          book['children'] = new_category[0]

  return {"name": file, "children": new_data['children'][0]['children']}

# only_one_type_entities(data, ent='GPE')

jane_austen_places = only_one_type_entities('American Realism', ent='GPE', min=5)

# dumps = json.dumps(jane_austen_places, indent=4)  

# with open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/jane_austen_places.json", "w") as outfile:
#     outfile.write(dumps)

jane_austen_places
# Out:
# {'name': 'American Realism',
#  'children': [{'name': 'Mark Twain',
#    'children': [{'name': 'The Prince and The Pauper',
#      'children': [{'name': 'England', 'value': 52},
#       {'name': 'London', 'value': 29},
#       {'name': 'Westminster', 'value': 8},
#       {'name': 'Southwark', 'value': 8}]},
#     {'name': "A Connecticut Yankee in King Arthur's Court",
#      'children': [{'name': 'England', 'value': 32},
#       {'name': 'London', 'value': 15},
#       {'name': 'Britain', 'value': 14},
#       {'name': 'Ireland', 'value': 7}]},
#     {'name': 'Life on the Mississippi',
#      'children': [{'name': 'New Orleans', 'value': 104},
#       {'name': 'StLouis', 'value': 77},
#       {'name': 'Cairo', 'value': 31},
#       {'name': 'Vicksburg', 'value': 28},
#       {'name': 'Missouri', 'value': 26},
#       {'name': 'Memphis', 'value': 26},
#       {'name': 'Arkansas', 'value': 23},
#       {'name': 'StPaul', 'value': 22},
#       {'name': 'Orleans', 'value': 19},
#       {'name': 'Natchez', 'value': 17},
#       {'name': 'Ohio', 'value': 16},
#       {'name': 'Cincinnati', 'value': 16},
#       {'name': 'Illinois', 'value': 15},
#       {'name': 'Louisiana', 'value': 14},
#       {'name': 'Troy', 'value': 13},
#       {'name': 'England', 'value': 11},
#       {'name': 'Kentucky', 'value': 10},
#       {'name': 'Union', 'value': 9},
#       {'name': 'Minneapolis', 'value': 9},
#       {'name': 'Pennsylvania', 'value': 9},
#       {'name': 'Hannibal', 'value': 9},
#       {'name': 'America', 'value': 9},
#       {'name': 'New York', 'value': 9},
#       {'name': 'the United States', 'value': 9},
#       {'name': 'Keokuk', 'value': 8},
#       {'name': 'St.', 'value': 8},
#       {'name': 'Tennessee', 'value': 8},
#       {'name': 'France', 'value': 7},
#       {'name': 'Helena', 'value': 7},
#       {'name': 'United States', 'value': 7},
#       {'name': 'Baton Rouge', 'value': 7},
#       {'name': 'Winona', 'value': 7},
#       {'name': 'Davenport', 'value': 6},
#       {'name': 'Chicago', 'value': 6},
#       {'name': 'New\r', 'value': 6},
#       {'name': 'Manchester', 'value': 6}]},
#     {'name': "The Tragedy of Pudd'nhead Wilson",
#      'children': [{'name': 'StLouis', 'value': 14},
#       {'name': 'Missouri', 'value': 6}]},
#     {'name': 'The Adventures of Tom Sawyer',
#      'children': [{'name': 'StPetersburg', 'value': 6}]},
#     {'name': 'Adventures of Huckleberry Finn',
#      'children': [{'name': 'Illinois', 'value': 15},
#       {'name': 'England', 'value': 14},
#       {'name': 'Orleans', 'value': 10},
#       {'name': 'Cairo', 'value': 9},
#       {'name': 'Providence', 'value': 8},
#       {'name': 'Goshen', 'value': 6},
#       {'name': 'Bilgewater', 'value': 6},
#       {'name': 'StLouis', 'value': 6}]},
#     {'name': 'Innocents Abroad',
#      'children': [{'name': 'Jerusalem', 'value': 79},
#       {'name': 'Paris', 'value': 66},
#       {'name': 'Rome', 'value': 65},
#       {'name': 'Damascus', 'value': 64},
#       {'name': 'America', 'value': 58},
#       {'name': 'France', 'value': 52},
#       {'name': 'Palestine', 'value': 52},
#       {'name': 'Italy', 'value': 48},
#       {'name': 'Venice', 'value': 48},
#       {'name': 'Constantinople', 'value': 45},
#       {'name': 'Egypt', 'value': 39},
#       {'name': 'Naples', 'value': 35},
#       {'name': 'Ephesus', 'value': 34},
#       {'name': 'Jordan', 'value': 33},
#       {'name': 'Smyrna', 'value': 33},
#       {'name': 'Gibraltar', 'value': 33},
#       {'name': 'Genoa', 'value': 31},
#       {'name': 'Spain', 'value': 30},
#       {'name': 'Syria', 'value': 26},
#       {'name': 'Florence', 'value': 26},
#       {'name': 'Russia', 'value': 26},
#       {'name': 'Nazareth', 'value': 24},
#       {'name': 'Tangier', 'value': 23},
#       {'name': 'Milan', 'value': 20},
#       {'name': 'Pompeii', 'value': 20},
#       {'name': 'Athens', 'value': 20},
#       {'name': 'Baalbec', 'value': 19},
#       {'name': 'Israel', 'value': 19},
#       {'name': 'Tahoe', 'value': 18},
#       {'name': 'Greece', 'value': 18},
#       {'name': 'New York', 'value': 17},
#       {'name': 'Tiberias', 'value': 16},
#       {'name': 'Jaffa', 'value': 16},
#       {'name': 'Capernaum', 'value': 15},
#       {'name': 'Magdala', 'value': 14},
#       {'name': 'Jericho', 'value': 14},
#       {'name': 'Shechem', 'value': 13},
#       {'name': 'England', 'value': 13},
#       {'name': 'Leghorn', 'value': 12},
#       {'name': 'Bethlehem', 'value': 12},
#       {'name': 'Marseilles', 'value': 12},
#       {'name': 'Samaria', 'value': 12},
#       {'name': 'Sebastopol', 'value': 12},
#       {'name': 'Beirout', 'value': 11},
#       {'name': 'Alexandria', 'value': 11},
#       {'name': 'Morocco', 'value': 11},
#       {'name': 'Turkey', 'value': 10},
#       {'name': 'Piraeus', 'value': 10},
#       {'name': 'Pisa', 'value': 10},
#       {'name': 'Versailles', 'value': 9},
#       {'name': 'the United States', 'value': 8},
#       {'name': 'Fayal', 'value': 8},
#       {'name': 'Tabor', 'value': 8},
#       {'name': 'Lyons', 'value': 8},
#       {'name': 'Lebanon', 'value': 8},
#       {'name': 'Arabia', 'value': 7},
#       {'name': 'Mecca', 'value': 7},
#       {'name': 'Nevada', 'value': 6},
#       {'name': 'Odessa', 'value': 6},
#       {'name': 'Joppa', 'value': 6},
#       {'name': 'Stamboul', 'value': 6},
#       {'name': 'Washington', 'value': 6},
#       {'name': 'Como', 'value': 6},
#       {'name': 'San Francisco', 'value': 6}]}]}]}

# %%
### Subdivide Alphabetically with Minimum

def subdivide_alphabetically(file, min=50):

  f = open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file}.json")

  data = json.load(f)

  new_data = data

  authors = new_data['children'][0]['children']
  for author in authors:
    for book in author['children']:
      for category in book['children']:
        for subcategory in category['children']:
          new_children = []
          for word in subcategory['children']:
            if word['value'] > min:
              new_children.append(word)
          subcategory['children'] = new_children
          letter_set = list(set([word['name'][0].upper() for word in subcategory['children']]))
          letter_set.sort()
          alphabetized = [{"name":letter, "children":[]} for letter in letter_set]
          # print(alphabetized)

          
          for alphabet in alphabetized:
            for word in subcategory['children']:
              if word['name'][0].upper() == alphabet['name']:
                alphabet['children'].append(word)
          subcategory['children'] = alphabetized
         

  return new_data

file = 'American Realism'

min = 25

new_data = subdivide_alphabetically(file, min=min)

dumps = json.dumps(new_data, indent=4)  

with open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/{file.lower().replace(' ','_')}_alphabetized_min_{min}.json", "w") as outfile:
    outfile.write(dumps)

# %%
categories = ['Modernism',
 'American Realism',
 'Proto-Modernism',
 'Victorian',
 'Augustan literature',
 'Genre Fiction',
 'Romanticism']

full_literature_data = {
    "name": 'literature',
    "children" : [only_one_type_entities(cat, ent='PERSON', min=5) for cat in categories]

}

dumps = json.dumps(full_literature_data, indent=4)  

with open(f"/content/drive/MyDrive/NLP_2023/lit_breakdown/full_lit_alphabetized_PERSON.json", "w") as outfile:
    outfile.write(dumps)
